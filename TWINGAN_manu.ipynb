# %% [markdown]
# <a href="https://colab.research.google.com/github/mrm8488/TwinGAN/blob/master/TWINGAN_manu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Colab Noteboot to play with [TwinGAN](https://github.com/jerryli27/TwinGAN)
# ### Unsupervised Image Translation for Human Portraits
#
# > by Manuel Romero
#
# [Webpage](https://mrm8488.github.io)
#
# [Twitter @mrm8488](https://twitter.com/mrm8488)

# %%
# !git clone https://github.com/mrm8488/TwinGAN.git
# Out:
# Cloning into 'TwinGAN'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 388 (delta 0), reused 0 (delta 0), pack-reused 384
# Receiving objects: 100% (388/388), 56.11 MiB | 44.54 MiB/s, done.
# Resolving deltas: 100% (116/116), done.

# %%
# !pip install gdown

# %%
model1_id = "1dXfqAODQxB2uNhyQANtZICAjwhNMWnbl"
model2_id = "1UJEqlH_1sfdmWs6MXKV4H69NGad0rdUB"
# !gdown https://drive.google.com/uc?id=$model1_id
# !gdown https://drive.google.com/uc?id=$model2_id
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1dXfqAODQxB2uNhyQANtZICAjwhNMWnbl
# To: /content/twingan_256.zip
# 240MB [00:01, 189MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1UJEqlH_1sfdmWs6MXKV4H69NGad0rdUB
# To: /content/human_to_cat_128.zip
# 239MB [00:01, 160MB/s]

# %%
# !unzip "/content/twingan_256.zip"
# !unzip "/content/human_to_cat_128.zip"
# !rm -rf "/content/twingan_256.zip"
# !rm -rf "/content/human_to_cat_128.zip"
# Out:
# Archive:  /content/twingan_256.zip
#    creating: 256/
#   inflating: 256/checkpoint
#   inflating: 256/flags.txt
#   inflating: 256/graph.pbtxt
#   inflating: 256/model.ckpt-100000.data-00000-of-00001
#   inflating: 256/model.ckpt-100000.index
#   inflating: 256/model.ckpt-100000.meta
# Archive:  /content/human_to_cat_128.zip
#    creating: 128/
#   inflating: 128/checkpoint
#   inflating: 128/flags.txt
#   inflating: 128/graph.pbtxt
#   inflating: 128/model.ckpt-741475.data-00000-of-00001
#   inflating: 128/model.ckpt-741475.index
#   inflating: 128/model.ckpt-741475.meta

# %%
# !ls -l
# Out:
# total 16
# drwxrwxrwx  2 root root 4096 Jul  3  2018 128
# drwxrwxrwx  2 root root 4096 Jun 23  2018 256
# drwxr-xr-x  1 root root 4096 Oct 22 15:18 sample_data
# drwxr-xr-x 13 root root 4096 Oct 27 07:37 TwinGAN

# %%
cd TwinGAN
# Out:
# /content/TwinGAN

# %%
# !rm -rf /content/TwinGAN/demo/inference_input/cropped/*
# !rm -rf /content/TwinGAN/demo/inference_output/anime/*
# !rm -rf /content/TwinGAN/demo/inference_output/cat/*

# %%
#@title Choose a mode

model = 'human2cat' #@param ["human2anime", "human2cat"]

models = {'human2anime': '/content/256/', 'human2cat': '/content/128/'}
model_path = models[model]
image_hw = model_path.split("/")[2]
output_folder = "anime" if image_hw == "256" else "cat"
print(model_path)
print(image_hw)
print(output_folder)
# Out:
# /content/128/
# 128
# cat

# %% [markdown]
# ## Choose a picture form your local filesystem:

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ed2d904a-736f-4370-bfb9-ea457a517b5a" name="files[]" multiple disabled />
#      <output id="result-ed2d904a-736f-4370-bfb9-ea457a517b5a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving selfie1-nobg.png to selfie1-nobg.png

# %%
uploaded_file = ""
for filename in uploaded.keys():
  uploaded_file = filename
  # !mv ./$filename ./demo/inference_input/cropped/$filename

# %%
# %time !python inference/image_translation_infer.py --model_path=$model_path --image_hw=$image_hw --input_tensor_name="sources_ph" --output_tensor_name="custom_generated_t_style_source:0" --input_image_path="./demo/inference_input/cropped/" --output_image_path="./demo/inference_output/$output_folder/" > /dev/null
print("DONE!")
# Out:
# /usr/local/lib/python3.6/dist-packages/absl/flags/_validators.py:359: UserWarning: Flag --model_path has a non-None default value; therefore, mark_flag_as_required will pass even if flag is not specified in the command line!
#   'command line!' % flag_name)
# WARNING:tensorflow:From inference/image_translation_infer.py:128: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From inference/image_translation_infer.py:50: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W1027 08:25:21.221727 140463115360128 module_wrapper.py:139] From inference/image_translation_infer.py:50: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From inference/image_translation_infer.py:51: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W1027 08:25:21.222032 140463115360128 module_wrapper.py:139] From inference/image_translation_infer.py:51: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-10-27 08:25:21.227771: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-10-27 08:25:21.228022: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1a7f800 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2019-10-27 08:25:21.228053: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# WARNING:tensorflow:From inference/image_translation_infer.py:55: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1027 08:25:21.228649 140463115360128 module_wrapper.py:139] From inference/image_translation_infer.py:55: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From inference/image_translation_infer.py:57: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# W1027 08:25:21.236665 140463115360128 module_wrapper.py:139] From inference/image_translation_infer.py:57: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From ./util_io.py:169: The name tf.train.import_meta_graph is deprecated. Please use tf.compat.v1.train.import_meta_graph instead.
#
# W1027 08:25:21.243964 140463115360128 module_wrapper.py:139] From ./util_io.py:169: The name tf.train.import_meta_graph is deprecated. Please use tf.compat.v1.train.import_meta_graph instead.
#
# 2019-10-27 08:25:24.387965: W tensorflow/core/graph/graph_constructor.cc:1491] Importing a graph with a lower producer version 26 into an existing graph with producer version 134. Shape inference will have run different parts of the graph with different producer versions.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/queue_runner_impl.py:391: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W1027 08:25:34.091926 140463115360128 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/queue_runner_impl.py:391: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From ./util_io.py:170: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W1027 08:25:34.114835 140463115360128 module_wrapper.py:139] From ./util_io.py:170: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# INFO:tensorflow:Restoring parameters from /content/128/model.ckpt-741475
# I1027 08:25:34.116110 140463115360128 saver.py:1284] Restoring parameters from /content/128/model.ckpt-741475
# 2019-10-27 08:25:35.470009: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# IsVariableInitialized: CPU
# ApplyAdam: CPU
# Add: CPU XLA_CPU
# RefSwitch: CPU
# Identity: CPU XLA_CPU
# RandomStandardNormal: CPU XLA_CPU
# VariableV2: CPU
# Const: CPU XLA_CPU
# Mul: CPU XLA_CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   encoder_content/from_rgb_128x128/Conv/weights/Initializer/random_normal/shape (Const) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/weights/Initializer/random_normal/mean (Const) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/weights/Initializer/random_normal/stddev (Const) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/weights/Initializer/random_normal/RandomStandardNormal (RandomStandardNormal) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/weights/Initializer/random_normal/mul (Mul) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/weights/Initializer/random_normal (Add) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/weights (VariableV2) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/weights/Assign (Assign) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/weights/read (Identity) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/weights/Adam/Initializer/zeros (Const) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/weights/Adam (VariableV2) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/weights/Adam/Assign (Assign) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/weights/Adam/read (Identity) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/weights/Adam_1/Initializer/zeros (Const) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/weights/Adam_1 (VariableV2) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/weights/Adam_1/Assign (Assign) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/weights/Adam_1/read (Identity) /device:GPU:0
#   cond_2/Adam/update_encoder_content/from_rgb_128x128/Conv/weights/ApplyAdam/Switch (RefSwitch) /device:GPU:0
#   cond_2/Adam/update_encoder_content/from_rgb_128x128/Conv/weights/ApplyAdam/Switch_1 (RefSwitch) /device:GPU:0
#   cond_2/Adam/update_encoder_content/from_rgb_128x128/Conv/weights/ApplyAdam/Switch_2 (RefSwitch) /device:GPU:0
#   cond_2/Adam/update_encoder_content/from_rgb_128x128/Conv/weights/ApplyAdam (ApplyAdam) /device:GPU:0
#   save/Assign_536 (Assign) /device:GPU:0
#   save/Assign_537 (Assign) /device:GPU:0
#   save/Assign_538 (Assign) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_1 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_508 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_509 (IsVariableInitialized) /device:GPU:0
#
# 2019-10-27 08:25:35.473774: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# IsVariableInitialized: CPU
# ApplyAdam: CPU
# Const: CPU XLA_CPU
# Assign: CPU
# VariableV2: CPU
# Identity: CPU XLA_CPU
# RefSwitch: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/beta_s/Initializer/zeros (Const) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/beta_s (VariableV2) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/beta_s/Assign (Assign) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/beta_s/read (Identity) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/beta_s/Adam/Initializer/zeros (Const) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/beta_s/Adam (VariableV2) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/beta_s/Adam/Assign (Assign) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/beta_s/Adam/read (Identity) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/beta_s/Adam_1/Initializer/zeros (Const) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/beta_s/Adam_1 (VariableV2) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/beta_s/Adam_1/Assign (Assign) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/beta_s/Adam_1/read (Identity) /device:GPU:0
#   cond_2/Adam/update_encoder_content/from_rgb_128x128/Conv/BatchNorm/beta_s/ApplyAdam/Switch (RefSwitch) /device:GPU:0
#   cond_2/Adam/update_encoder_content/from_rgb_128x128/Conv/BatchNorm/beta_s/ApplyAdam/Switch_1 (RefSwitch) /device:GPU:0
#   cond_2/Adam/update_encoder_content/from_rgb_128x128/Conv/BatchNorm/beta_s/ApplyAdam/Switch_2 (RefSwitch) /device:GPU:0
#   cond_2/Adam/update_encoder_content/from_rgb_128x128/Conv/BatchNorm/beta_s/ApplyAdam (ApplyAdam) /device:GPU:0
#   save/Assign_512 (Assign) /device:GPU:0
#   save/Assign_513 (Assign) /device:GPU:0
#   save/Assign_514 (Assign) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_2 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_510 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_511 (IsVariableInitialized) /device:GPU:0
#
# 2019-10-27 08:25:35.477122: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# IsVariableInitialized: CPU
# ApplyAdam: CPU
# Const: CPU XLA_CPU
# Assign: CPU
# VariableV2: CPU
# Identity: CPU XLA_CPU
# RefSwitch: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/gamma_s/Initializer/ones (Const) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/gamma_s (VariableV2) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/gamma_s/Assign (Assign) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/gamma_s/read (Identity) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/gamma_s/Adam/Initializer/zeros (Const) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/gamma_s/Adam (VariableV2) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/gamma_s/Adam/Assign (Assign) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/gamma_s/Adam/read (Identity) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/gamma_s/Adam_1/Initializer/zeros (Const) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/gamma_s/Adam_1 (VariableV2) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/gamma_s/Adam_1/Assign (Assign) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/gamma_s/Adam_1/read (Identity) /device:GPU:0
#   cond_2/Adam/update_encoder_content/from_rgb_128x128/Conv/BatchNorm/gamma_s/ApplyAdam/Switch (RefSwitch) /device:GPU:0
#   cond_2/Adam/update_encoder_content/from_rgb_128x128/Conv/BatchNorm/gamma_s/ApplyAdam/Switch_1 (RefSwitch) /device:GPU:0
#   cond_2/Adam/update_encoder_content/from_rgb_128x128/Conv/BatchNorm/gamma_s/ApplyAdam/Switch_2 (RefSwitch) /device:GPU:0
#   cond_2/Adam/update_encoder_content/from_rgb_128x128/Conv/BatchNorm/gamma_s/ApplyAdam (ApplyAdam) /device:GPU:0
#   save/Assign_518 (Assign) /device:GPU:0
#   save/Assign_519 (Assign) /device:GPU:0
#   save/Assign_520 (Assign) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_3 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_512 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_513 (IsVariableInitialized) /device:GPU:0
#
# 2019-10-27 08:25:35.480179: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# IsVariableInitialized: CPU
# RealDiv: CPU XLA_CPU
# AssignSub: CPU
# Const: CPU XLA_CPU
# Mul: CPU XLA_CPU
# Assign: CPU
# VariableV2: CPU
# Identity: CPU XLA_CPU
# Sub: CPU XLA_CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/moving_mean_s/Initializer/zeros (Const) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/moving_mean_s (VariableV2) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/moving_mean_s/Assign (Assign) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/moving_mean_s/read (Identity) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/renorm_mean_s/Initializer/zeros (Const) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/renorm_mean_s (VariableV2) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/renorm_mean_s/Assign (Assign) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/renorm_mean_s/read (Identity) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/renorm_mean_weight_s/Initializer/zeros (Const) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/renorm_mean_weight_s (VariableV2) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/renorm_mean_weight_s/Assign (Assign) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/renorm_mean_weight_s/read (Identity) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/Identity_2 (Identity) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/Const (Const) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg/decay (Const) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg/sub (Sub) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg/mul (Mul) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg (AssignSub) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_1/decay (Const) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_1/sub (Sub) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_1/mul (Mul) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_1 (AssignSub) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/div_2 (RealDiv) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_4/decay (Const) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_4/sub (Sub) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_4/mul (Mul) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_4 (AssignSub) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/Identity_2 (Identity) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/Const (Const) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg/decay (Const) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg/sub (Sub) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg/mul (Mul) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg (AssignSub) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_1/decay (Const) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_1/sub (Sub) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_1/mul (Mul) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_1 (AssignSub) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/div_2 (RealDiv) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_4/decay (Const) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_4/sub (Sub) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_4/mul (Mul) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_4 (AssignSub) /device:GPU:0
#   save/Assign_524 (Assign) /device:GPU:0
#   save/Assign_528 (Assign) /device:GPU:0
#   save/Assign_530 (Assign) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_4 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_6 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_7 (IsVariableInitialized) /device:GPU:0
#
# 2019-10-27 08:25:35.482658: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# IsVariableInitialized: CPU
# Square: CPU XLA_CPU
# RealDiv: CPU XLA_CPU
# AssignSub: CPU
# Const: CPU XLA_CPU
# Mul: CPU XLA_CPU
# Assign: CPU
# VariableV2: CPU
# Identity: CPU XLA_CPU
# Sub: CPU XLA_CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/moving_variance_s/Initializer/ones (Const) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/moving_variance_s (VariableV2) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/moving_variance_s/Assign (Assign) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/moving_variance_s/read (Identity) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/renorm_stddev_s/Initializer/zeros (Const) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/renorm_stddev_s (VariableV2) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/renorm_stddev_s/Assign (Assign) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/renorm_stddev_s/read (Identity) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/renorm_stddev_weight_s/Initializer/zeros (Const) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/renorm_stddev_weight_s (VariableV2) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/renorm_stddev_weight_s/Assign (Assign) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/renorm_stddev_weight_s/read (Identity) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/Identity_3 (Identity) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/Const_1 (Const) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_2/decay (Const) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_2/sub (Sub) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_2/mul (Mul) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_2 (AssignSub) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_3/decay (Const) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_3/sub (Sub) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_3/mul (Mul) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_3 (AssignSub) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/div_3 (RealDiv) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/Square (Square) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/sub_3/y (Const) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/sub_3 (Sub) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_5/decay (Const) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_5/sub (Sub) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_5/mul (Mul) /device:GPU:0
#   encoder_content/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_5 (AssignSub) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/Identity_3 (Identity) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/Const_1 (Const) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_2/decay (Const) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_2/sub (Sub) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_2/mul (Mul) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_2 (AssignSub) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_3/decay (Const) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_3/sub (Sub) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_3/mul (Mul) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_3 (AssignSub) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/div_3 (RealDiv) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/Square (Square) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/sub_3/y (Const) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/sub_3 (Sub) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_5/decay (Const) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_5/sub (Sub) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_5/mul (Mul) /device:GPU:0
#   encoder_content_3/from_rgb_128x128/Conv/BatchNorm/AssignMovingAvg_5 (AssignSub) /device:GPU:0
#   save/Assign_526 (Assign) /device:GPU:0
#   save/Assign_532 (Assign) /device:GPU:0
#   save/Assign_534 (Assign) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_5 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_8 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_9 (IsVariableInitialized) /device:GPU:0
#
# 2019-10-27 08:25:35.565558: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# IsVariableInitialized: CPU
# ApplyAdam: CPU
# Add: CPU XLA_CPU
# RefSwitch: CPU
# Identity: CPU XLA_CPU
# RandomStandardNormal: CPU XLA_CPU
# VariableV2: CPU
# Fill: CPU XLA_CPU
# Const: CPU XLA_CPU
# Mul: CPU XLA_CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   encoder_content/encoder_block_128x128x64/Conv/weights/Initializer/random_normal/shape (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/weights/Initializer/random_normal/mean (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/weights/Initializer/random_normal/stddev (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/weights/Initializer/random_normal/RandomStandardNormal (RandomStandardNormal) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/weights/Initializer/random_normal/mul (Mul) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/weights/Initializer/random_normal (Add) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/weights (VariableV2) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/weights/Assign (Assign) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/weights/read (Identity) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/weights/Adam/Initializer/zeros/shape_as_tensor (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/weights/Adam/Initializer/zeros/Const (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/weights/Adam/Initializer/zeros (Fill) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/weights/Adam (VariableV2) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/weights/Adam/Assign (Assign) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/weights/Adam/read (Identity) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/weights/Adam_1/Initializer/zeros/shape_as_tensor (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/weights/Adam_1/Initializer/zeros/Const (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/weights/Adam_1/Initializer/zeros (Fill) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/weights/Adam_1 (VariableV2) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/weights/Adam_1/Assign (Assign) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/weights/Adam_1/read (Identity) /device:GPU:0
#   cond_2/Adam/update_encoder_content/encoder_block_128x128x64/Conv/weights/ApplyAdam/Switch (RefSwitch) /device:GPU:0
#   cond_2/Adam/update_encoder_content/encoder_block_128x128x64/Conv/weights/ApplyAdam/Switch_1 (RefSwitch) /device:GPU:0
#   cond_2/Adam/update_encoder_content/encoder_block_128x128x64/Conv/weights/ApplyAdam/Switch_2 (RefSwitch) /device:GPU:0
#   cond_2/Adam/update_encoder_content/encoder_block_128x128x64/Conv/weights/ApplyAdam (ApplyAdam) /device:GPU:0
#   save/Assign_194 (Assign) /device:GPU:0
#   save/Assign_195 (Assign) /device:GPU:0
#   save/Assign_196 (Assign) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_10 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_514 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_515 (IsVariableInitialized) /device:GPU:0
#
# 2019-10-27 08:25:35.569476: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# Mul: CPU XLA_CPU
# IsVariableInitialized: CPU
# ApplyAdam: CPU
# Const: CPU XLA_CPU
# Switch: CPU XLA_CPU
# Assign: CPU
# VariableV2: CPU
# Identity: CPU XLA_CPU
# RefSwitch: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/beta_s/Initializer/zeros (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/beta_s (VariableV2) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/beta_s/Assign (Assign) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/beta_s/read (Identity) /device:GPU:0
#   cond_2/beta1_power/initial_value (Const) /device:GPU:0
#   cond_2/beta1_power (VariableV2) /device:GPU:0
#   cond_2/beta1_power/Assign (Assign) /device:GPU:0
#   cond_2/beta1_power/read (Identity) /device:GPU:0
#   cond_2/beta2_power/initial_value (Const) /device:GPU:0
#   cond_2/beta2_power (VariableV2) /device:GPU:0
#   cond_2/beta2_power/Assign (Assign) /device:GPU:0
#   cond_2/beta2_power/read (Identity) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/beta_s/Adam/Initializer/zeros (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/beta_s/Adam (VariableV2) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/beta_s/Adam/Assign (Assign) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/beta_s/Adam/read (Identity) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/beta_s/Adam_1/Initializer/zeros (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/beta_s/Adam_1 (VariableV2) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/beta_s/Adam_1/Assign (Assign) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/beta_s/Adam_1/read (Identity) /device:GPU:0
#   cond_2/Adam/update_encoder_content/from_rgb_128x128/Conv/weights/ApplyAdam/Switch_3 (Switch) /device:GPU:0
#   cond_2/Adam/update_encoder_content/from_rgb_128x128/Conv/weights/ApplyAdam/Switch_4 (Switch) /device:GPU:0
#   cond_2/Adam/update_encoder_content/encoder_block_128x128x64/Conv/BatchNorm/beta_s/ApplyAdam/Switch (RefSwitch) /device:GPU:0
#   cond_2/Adam/update_encoder_content/encoder_block_128x128x64/Conv/BatchNorm/beta_s/ApplyAdam/Switch_1 (RefSwitch) /device:GPU:0
#   cond_2/Adam/update_encoder_content/encoder_block_128x128x64/Conv/BatchNorm/beta_s/ApplyAdam/Switch_2 (RefSwitch) /device:GPU:0
#   cond_2/Adam/update_encoder_content/encoder_block_128x128x64/Conv/BatchNorm/beta_s/ApplyAdam (ApplyAdam) /device:GPU:0
#   cond_2/Adam/mul (Mul) /device:GPU:0
#   cond_2/Adam/Assign/Switch (RefSwitch) /device:GPU:0
#   cond_2/Adam/Assign (Assign) /device:GPU:0
#   cond_2/Adam/mul_1 (Mul) /device:GPU:0
#   cond_2/Adam/Assign_1/Switch (RefSwitch) /device:GPU:0
#   cond_2/Adam/Assign_1 (Assign) /device:GPU:0
#   cond_2/Adam_1/update_discriminator_s/from_rgb_128x128/Conv/weights/ApplyAdam/Switch_3 (Switch) /device:GPU:0
#   cond_2/Adam_1/update_discriminator_s/from_rgb_128x128/Conv/weights/ApplyAdam/Switch_4 (Switch) /device:GPU:0
#   cond_2/Adam_1/mul (Mul) /device:GPU:0
#   cond_2/Adam_1/Assign/Switch (RefSwitch) /device:GPU:0
#   cond_2/Adam_1/Assign (Assign) /device:GPU:0
#   cond_2/Adam_1/mul_1 (Mul) /device:GPU:0
#   cond_2/Adam_1/Assign_1/Switch (RefSwitch) /device:GPU:0
#   cond_2/Adam_1/Assign_1 (Assign) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#   save/Assign_1 (Assign) /device:GPU:0
#   save/Assign_170 (Assign) /device:GPU:0
#   save/Assign_171 (Assign) /device:GPU:0
#   save/Assign_172 (Assign) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_11 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_506 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_507 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_516 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_517 (IsVariableInitialized) /device:GPU:0
#
# 2019-10-27 08:25:35.573135: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# IsVariableInitialized: CPU
# ApplyAdam: CPU
# Const: CPU XLA_CPU
# Assign: CPU
# VariableV2: CPU
# Identity: CPU XLA_CPU
# RefSwitch: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/gamma_s/Initializer/ones (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/gamma_s (VariableV2) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/gamma_s/Assign (Assign) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/gamma_s/read (Identity) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/gamma_s/Adam/Initializer/zeros (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/gamma_s/Adam (VariableV2) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/gamma_s/Adam/Assign (Assign) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/gamma_s/Adam/read (Identity) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/gamma_s/Adam_1/Initializer/zeros (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/gamma_s/Adam_1 (VariableV2) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/gamma_s/Adam_1/Assign (Assign) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/gamma_s/Adam_1/read (Identity) /device:GPU:0
#   cond_2/Adam/update_encoder_content/encoder_block_128x128x64/Conv/BatchNorm/gamma_s/ApplyAdam/Switch (RefSwitch) /device:GPU:0
#   cond_2/Adam/update_encoder_content/encoder_block_128x128x64/Conv/BatchNorm/gamma_s/ApplyAdam/Switch_1 (RefSwitch) /device:GPU:0
#   cond_2/Adam/update_encoder_content/encoder_block_128x128x64/Conv/BatchNorm/gamma_s/ApplyAdam/Switch_2 (RefSwitch) /device:GPU:0
#   cond_2/Adam/update_encoder_content/encoder_block_128x128x64/Conv/BatchNorm/gamma_s/ApplyAdam (ApplyAdam) /device:GPU:0
#   save/Assign_176 (Assign) /device:GPU:0
#   save/Assign_177 (Assign) /device:GPU:0
#   save/Assign_178 (Assign) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_12 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_518 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_519 (IsVariableInitialized) /device:GPU:0
#
# 2019-10-27 08:25:35.576769: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# IsVariableInitialized: CPU
# RealDiv: CPU XLA_CPU
# AssignSub: CPU
# Const: CPU XLA_CPU
# Mul: CPU XLA_CPU
# Assign: CPU
# VariableV2: CPU
# Identity: CPU XLA_CPU
# Sub: CPU XLA_CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/moving_mean_s/Initializer/zeros (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/moving_mean_s (VariableV2) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/moving_mean_s/Assign (Assign) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/moving_mean_s/read (Identity) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/renorm_mean_s/Initializer/zeros (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/renorm_mean_s (VariableV2) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/renorm_mean_s/Assign (Assign) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/renorm_mean_s/read (Identity) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/renorm_mean_weight_s/Initializer/zeros (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/renorm_mean_weight_s (VariableV2) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/renorm_mean_weight_s/Assign (Assign) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/renorm_mean_weight_s/read (Identity) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/Identity_2 (Identity) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/Const (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg/decay (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg/sub (Sub) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg/mul (Mul) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg (AssignSub) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_1/decay (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_1/sub (Sub) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_1/mul (Mul) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_1 (AssignSub) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/div_2 (RealDiv) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_4/decay (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_4/sub (Sub) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_4/mul (Mul) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_4 (AssignSub) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/Identity_2 (Identity) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/Const (Const) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg/decay (Const) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg/sub (Sub) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg/mul (Mul) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg (AssignSub) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_1/decay (Const) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_1/sub (Sub) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_1/mul (Mul) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_1 (AssignSub) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/div_2 (RealDiv) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_4/decay (Const) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_4/sub (Sub) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_4/mul (Mul) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_4 (AssignSub) /device:GPU:0
#   save/Assign_182 (Assign) /device:GPU:0
#   save/Assign_186 (Assign) /device:GPU:0
#   save/Assign_188 (Assign) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_13 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_15 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_16 (IsVariableInitialized) /device:GPU:0
#
# 2019-10-27 08:25:35.672073: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# IsVariableInitialized: CPU
# Square: CPU XLA_CPU
# RealDiv: CPU XLA_CPU
# AssignSub: CPU
# Const: CPU XLA_CPU
# Mul: CPU XLA_CPU
# Assign: CPU
# VariableV2: CPU
# Identity: CPU XLA_CPU
# Sub: CPU XLA_CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/moving_variance_s/Initializer/ones (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/moving_variance_s (VariableV2) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/moving_variance_s/Assign (Assign) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/moving_variance_s/read (Identity) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/renorm_stddev_s/Initializer/zeros (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/renorm_stddev_s (VariableV2) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/renorm_stddev_s/Assign (Assign) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/renorm_stddev_s/read (Identity) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/renorm_stddev_weight_s/Initializer/zeros (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/renorm_stddev_weight_s (VariableV2) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/renorm_stddev_weight_s/Assign (Assign) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/renorm_stddev_weight_s/read (Identity) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/Identity_3 (Identity) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/Const_1 (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_2/decay (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_2/sub (Sub) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_2/mul (Mul) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_2 (AssignSub) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_3/decay (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_3/sub (Sub) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_3/mul (Mul) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_3 (AssignSub) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/div_3 (RealDiv) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/Square (Square) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/sub_3/y (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/sub_3 (Sub) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_5/decay (Const) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_5/sub (Sub) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_5/mul (Mul) /device:GPU:0
#   encoder_content/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_5 (AssignSub) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/Identity_3 (Identity) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/Const_1 (Const) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_2/decay (Const) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_2/sub (Sub) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_2/mul (Mul) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_2 (AssignSub) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_3/decay (Const) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_3/sub (Sub) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_3/mul (Mul) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_3 (AssignSub) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/div_3 (RealDiv) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/Square (Square) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/sub_3/y (Const) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/sub_3 (Sub) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_5/decay (Const) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_5/sub (Sub) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_5/mul (Mul) /device:GPU:0
#   encoder_content_3/encoder_block_128x128x64/Conv/BatchNorm/AssignMovingAvg_5 (AssignSub) /device:GPU:0
# ...
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# IsVariableInitialized: CPU
# ApplyAdam: CPU
# Const: CPU XLA_CPU
# Assign: CPU
# VariableV2: CPU
# Identity: CPU XLA_CPU
# RefSwitch: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   discriminator_t/before_fc_1x1x256/Conv/biases/Initializer/zeros (Const) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv/biases (VariableV2) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv/biases/Assign (Assign) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv/biases/read (Identity) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv/biases/Adam/Initializer/zeros (Const) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv/biases/Adam (VariableV2) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv/biases/Adam/Assign (Assign) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv/biases/Adam/read (Identity) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv/biases/Adam_1/Initializer/zeros (Const) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv/biases/Adam_1 (VariableV2) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv/biases/Adam_1/Assign (Assign) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv/biases/Adam_1/read (Identity) /device:GPU:0
#   cond_2/Adam_1/update_discriminator_t/before_fc_1x1x256/Conv/biases/ApplyAdam/Switch (RefSwitch) /device:GPU:0
#   cond_2/Adam_1/update_discriminator_t/before_fc_1x1x256/Conv/biases/ApplyAdam/Switch_1 (RefSwitch) /device:GPU:0
#   cond_2/Adam_1/update_discriminator_t/before_fc_1x1x256/Conv/biases/ApplyAdam/Switch_2 (RefSwitch) /device:GPU:0
#   cond_2/Adam_1/update_discriminator_t/before_fc_1x1x256/Conv/biases/ApplyAdam (ApplyAdam) /device:GPU:0
#   save/Assign_86 (Assign) /device:GPU:0
#   save/Assign_87 (Assign) /device:GPU:0
#   save/Assign_88 (Assign) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_500 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_882 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_883 (IsVariableInitialized) /device:GPU:0
#
# 2019-10-27 08:25:42.968854: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# IsVariableInitialized: CPU
# ApplyAdam: CPU
# Add: CPU XLA_CPU
# RefSwitch: CPU
# Identity: CPU XLA_CPU
# RandomStandardNormal: CPU XLA_CPU
# VariableV2: CPU
# Fill: CPU XLA_CPU
# Const: CPU XLA_CPU
# Mul: CPU XLA_CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   discriminator_t/before_fc_1x1x256/Conv_1/weights/Initializer/random_normal/shape (Const) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/weights/Initializer/random_normal/mean (Const) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/weights/Initializer/random_normal/stddev (Const) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/weights/Initializer/random_normal/RandomStandardNormal (RandomStandardNormal) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/weights/Initializer/random_normal/mul (Mul) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/weights/Initializer/random_normal (Add) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/weights (VariableV2) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/weights/Assign (Assign) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/weights/read (Identity) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/weights/Adam/Initializer/zeros/shape_as_tensor (Const) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/weights/Adam/Initializer/zeros/Const (Const) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/weights/Adam/Initializer/zeros (Fill) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/weights/Adam (VariableV2) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/weights/Adam/Assign (Assign) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/weights/Adam/read (Identity) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/weights/Adam_1/Initializer/zeros/shape_as_tensor (Const) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/weights/Adam_1/Initializer/zeros/Const (Const) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/weights/Adam_1/Initializer/zeros (Fill) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/weights/Adam_1 (VariableV2) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/weights/Adam_1/Assign (Assign) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/weights/Adam_1/read (Identity) /device:GPU:0
#   cond_2/Adam_1/update_discriminator_t/before_fc_1x1x256/Conv_1/weights/ApplyAdam/Switch (RefSwitch) /device:GPU:0
#   cond_2/Adam_1/update_discriminator_t/before_fc_1x1x256/Conv_1/weights/ApplyAdam/Switch_1 (RefSwitch) /device:GPU:0
#   cond_2/Adam_1/update_discriminator_t/before_fc_1x1x256/Conv_1/weights/ApplyAdam/Switch_2 (RefSwitch) /device:GPU:0
#   cond_2/Adam_1/update_discriminator_t/before_fc_1x1x256/Conv_1/weights/ApplyAdam (ApplyAdam) /device:GPU:0
#   save/Assign_95 (Assign) /device:GPU:0
#   save/Assign_96 (Assign) /device:GPU:0
#   save/Assign_97 (Assign) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_501 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_884 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_885 (IsVariableInitialized) /device:GPU:0
#
# 2019-10-27 08:25:42.972841: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# IsVariableInitialized: CPU
# ApplyAdam: CPU
# Const: CPU XLA_CPU
# Assign: CPU
# VariableV2: CPU
# Identity: CPU XLA_CPU
# RefSwitch: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   discriminator_t/before_fc_1x1x256/Conv_1/biases/Initializer/zeros (Const) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/biases (VariableV2) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/biases/Assign (Assign) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/biases/read (Identity) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/biases/Adam/Initializer/zeros (Const) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/biases/Adam (VariableV2) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/biases/Adam/Assign (Assign) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/biases/Adam/read (Identity) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/biases/Adam_1/Initializer/zeros (Const) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/biases/Adam_1 (VariableV2) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/biases/Adam_1/Assign (Assign) /device:GPU:0
#   discriminator_t/before_fc_1x1x256/Conv_1/biases/Adam_1/read (Identity) /device:GPU:0
#   cond_2/Adam_1/update_discriminator_t/before_fc_1x1x256/Conv_1/biases/ApplyAdam/Switch (RefSwitch) /device:GPU:0
#   cond_2/Adam_1/update_discriminator_t/before_fc_1x1x256/Conv_1/biases/ApplyAdam/Switch_1 (RefSwitch) /device:GPU:0
#   cond_2/Adam_1/update_discriminator_t/before_fc_1x1x256/Conv_1/biases/ApplyAdam/Switch_2 (RefSwitch) /device:GPU:0
#   cond_2/Adam_1/update_discriminator_t/before_fc_1x1x256/Conv_1/biases/ApplyAdam (ApplyAdam) /device:GPU:0
#   save/Assign_92 (Assign) /device:GPU:0
#   save/Assign_93 (Assign) /device:GPU:0
#   save/Assign_94 (Assign) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_502 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_886 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_887 (IsVariableInitialized) /device:GPU:0
#
# 2019-10-27 08:25:42.977144: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# IsVariableInitialized: CPU
# ApplyAdam: CPU
# Add: CPU XLA_CPU
# RefSwitch: CPU
# Identity: CPU XLA_CPU
# RandomStandardNormal: CPU XLA_CPU
# VariableV2: CPU
# Const: CPU XLA_CPU
# Mul: CPU XLA_CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   discriminator_t/prediction/fully_connected/weights/Initializer/random_normal/shape (Const) /device:GPU:0
#   discriminator_t/prediction/fully_connected/weights/Initializer/random_normal/mean (Const) /device:GPU:0
#   discriminator_t/prediction/fully_connected/weights/Initializer/random_normal/stddev (Const) /device:GPU:0
#   discriminator_t/prediction/fully_connected/weights/Initializer/random_normal/RandomStandardNormal (RandomStandardNormal) /device:GPU:0
#   discriminator_t/prediction/fully_connected/weights/Initializer/random_normal/mul (Mul) /device:GPU:0
#   discriminator_t/prediction/fully_connected/weights/Initializer/random_normal (Add) /device:GPU:0
#   discriminator_t/prediction/fully_connected/weights (VariableV2) /device:GPU:0
#   discriminator_t/prediction/fully_connected/weights/Assign (Assign) /device:GPU:0
#   discriminator_t/prediction/fully_connected/weights/read (Identity) /device:GPU:0
#   discriminator_t/prediction/fully_connected/weights/Adam/Initializer/zeros (Const) /device:GPU:0
#   discriminator_t/prediction/fully_connected/weights/Adam (VariableV2) /device:GPU:0
#   discriminator_t/prediction/fully_connected/weights/Adam/Assign (Assign) /device:GPU:0
#   discriminator_t/prediction/fully_connected/weights/Adam/read (Identity) /device:GPU:0
#   discriminator_t/prediction/fully_connected/weights/Adam_1/Initializer/zeros (Const) /device:GPU:0
#   discriminator_t/prediction/fully_connected/weights/Adam_1 (VariableV2) /device:GPU:0
#   discriminator_t/prediction/fully_connected/weights/Adam_1/Assign (Assign) /device:GPU:0
#   discriminator_t/prediction/fully_connected/weights/Adam_1/read (Identity) /device:GPU:0
#   cond_2/Adam_1/update_discriminator_t/prediction/fully_connected/weights/ApplyAdam/Switch (RefSwitch) /device:GPU:0
#   cond_2/Adam_1/update_discriminator_t/prediction/fully_connected/weights/ApplyAdam/Switch_1 (RefSwitch) /device:GPU:0
#   cond_2/Adam_1/update_discriminator_t/prediction/fully_connected/weights/ApplyAdam/Switch_2 (RefSwitch) /device:GPU:0
#   cond_2/Adam_1/update_discriminator_t/prediction/fully_connected/weights/ApplyAdam (ApplyAdam) /device:GPU:0
#   save/Assign_167 (Assign) /device:GPU:0
#   save/Assign_168 (Assign) /device:GPU:0
#   save/Assign_169 (Assign) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_503 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_888 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_889 (IsVariableInitialized) /device:GPU:0
#
# 2019-10-27 08:25:42.981034: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# IsVariableInitialized: CPU
# ApplyAdam: CPU
# Const: CPU XLA_CPU
# Assign: CPU
# VariableV2: CPU
# Identity: CPU XLA_CPU
# RefSwitch: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   discriminator_t/prediction/fully_connected/biases/Initializer/zeros (Const) /device:GPU:0
#   discriminator_t/prediction/fully_connected/biases (VariableV2) /device:GPU:0
#   discriminator_t/prediction/fully_connected/biases/Assign (Assign) /device:GPU:0
#   discriminator_t/prediction/fully_connected/biases/read (Identity) /device:GPU:0
#   discriminator_t/prediction/fully_connected/biases/Adam/Initializer/zeros (Const) /device:GPU:0
#   discriminator_t/prediction/fully_connected/biases/Adam (VariableV2) /device:GPU:0
#   discriminator_t/prediction/fully_connected/biases/Adam/Assign (Assign) /device:GPU:0
#   discriminator_t/prediction/fully_connected/biases/Adam/read (Identity) /device:GPU:0
#   discriminator_t/prediction/fully_connected/biases/Adam_1/Initializer/zeros (Const) /device:GPU:0
#   discriminator_t/prediction/fully_connected/biases/Adam_1 (VariableV2) /device:GPU:0
#   discriminator_t/prediction/fully_connected/biases/Adam_1/Assign (Assign) /device:GPU:0
#   discriminator_t/prediction/fully_connected/biases/Adam_1/read (Identity) /device:GPU:0
#   cond_2/Adam_1/update_discriminator_t/prediction/fully_connected/biases/ApplyAdam/Switch (RefSwitch) /device:GPU:0
#   cond_2/Adam_1/update_discriminator_t/prediction/fully_connected/biases/ApplyAdam/Switch_1 (RefSwitch) /device:GPU:0
#   cond_2/Adam_1/update_discriminator_t/prediction/fully_connected/biases/ApplyAdam/Switch_2 (RefSwitch) /device:GPU:0
#   cond_2/Adam_1/update_discriminator_t/prediction/fully_connected/biases/ApplyAdam (ApplyAdam) /device:GPU:0
#   save/Assign_164 (Assign) /device:GPU:0
#   save/Assign_165 (Assign) /device:GPU:0
#   save/Assign_166 (Assign) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_504 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_890 (IsVariableInitialized) /device:GPU:0
#   init_ops/report_uninitialized_variables/IsVariableInitialized_891 (IsVariableInitialized) /device:GPU:0
#
# WARNING:tensorflow:From inference/image_translation_infer.py:64: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1027 08:25:45.902653 140463115360128 module_wrapper.py:139] From inference/image_translation_infer.py:64: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# CPU times: user 357 ms, sys: 78.9 ms, total: 435 ms
# Wall time: 31.9 s
# DONE!

# %%
from matplotlib.pyplot import imshow
from PIL import Image
import numpy as np

# %matplotlib inline
pil_im = Image.open('demo/inference_output/'+output_folder+'/'+uploaded_file, 'r')
imshow(np.asarray(pil_im))
